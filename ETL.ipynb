# %%
#Importamos las librerías necesarias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Cargamos los datasets
tabla1 = pd.read_csv("data/tabla1.csv",  sep=";", skiprows=10, index_col=0)
tabla2 = pd.read_csv("data/tabla2.csv",  sep=";", skiprows=10, index_col=0)
tabla3 = pd.read_csv("data/tabla3.csv",  sep=";", skiprows=10, index_col=0)
tabla4 = pd.read_csv("data/tabla4.csv",  sep=";", skiprows=10, index_col=0)
tabla5 = pd.read_csv("data/tabla5.csv",  sep=";", skiprows=10, index_col=0)
tabla6 = pd.read_csv("data/tabla6.csv",  sep=";", skiprows=10, index_col=0)
tabla7 = pd.read_csv("data/tabla7.csv",  sep=";", skiprows=10, index_col=0)
tabla8= pd.read_csv("data/tabla8.csv",  sep=";", skiprows=10, index_col=0)

# %% [markdown]
# #### Exploración inicial de los datasets

# %%
tabla1.head()
# Out:
#       Region, development group, country or area of destination  \
# Index
# 1                                                  WORLD
# 2                                                  WORLD
# 3                                                  WORLD
# 4                                                  WORLD
# 5                                                  WORLD
#
#        Notes of destination  Location code of destination  \
# Index
# 1                       NaN                           900
# 2                       NaN                           900
# 3                       NaN                           900
# 4                       NaN                           900
# 5                       NaN                           900
#
#       Type of data of destination  \
# Index
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
#
# ...

# %%
tabla1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37051 entries, 1 to 37051
# Data columns (total 27 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Region, development group, country or area of destination  37051 non-null  object
#  1   Notes of destination                                       3574 non-null   float64
#  2   Location code of destination                               37051 non-null  int64
#  3   Type of data of destination                                23323 non-null  object
#  4   Region, development group, country or area of origin       37051 non-null  object
#  5   Location code of origin                                    37051 non-null  int64
#  6   1990                                                       37051 non-null  object
#  7   1995                                                       37051 non-null  object
# ...

# %%
tabla2.head()
# Out:
#                                Unnamed: 1  Notes of destination  \
# Index
# 1                                   WORLD                   NaN
# 2                      Sub-Saharan Africa                   NaN
# 3        Northern Africa and Western Asia                   NaN
# 4               Central and Southern Asia                   NaN
# 5          Eastern and South-Eastern Asia                   NaN
#
#        Location code of destination          900         947        1833  \
# Index
# 1                               900  280 598 105  28 284 538  37 563 820
# 2                               947   22 221 538  17 808 594   1 239 160
# 3                              1833   49 767 746   2 263 512  19 145 437
# 4                               921   19 427 576      56 069     330 579
# 5                              1832   19 591 106      14 862      29 006
#
#               921        1832        1830      1835  ...        915  \
# ...

# %%
tabla2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, 1 to 48
# Data columns (total 52 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 1                    48 non-null     object
#  1   Notes of destination          0 non-null      float64
#  2   Location code of destination  48 non-null     int64
#  3   900                           48 non-null     object
#  4   947                           48 non-null     object
#  5   1833                          48 non-null     object
#  6   921                           48 non-null     object
#  7   1832                          48 non-null     object
#  8   1830                          48 non-null     object
#  9   1835                          48 non-null     object
#  10  927                           48 non-null     object
#  11  1829                          48 non-null     object
# ...

# %%
tabla3.head()
# Out:
#                                Unnamed: 1  Notes of destination  \
# Index
# 1                                   WORLD                   NaN
# 2                      Sub-Saharan Africa                   NaN
# 3        Northern Africa and Western Asia                   NaN
# 4               Central and Southern Asia                   NaN
# 5          Eastern and South-Eastern Asia                   NaN
#
#        Location code of destination          900         947        1833  \
# Index
# 1                               900  247 958 644  24 197 211  32 606 047
# 2                               947   20 721 874  16 017 580   1 145 027
# 3                              1833   42 036 092   1 411 666  16 701 758
# 4                               921   19 266 265      59 931     346 590
# 5                              1832   18 027 810      10 449      27 424
#
#               921        1832        1830      1835  ...        915  \
# ...

# %%
tabla3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, 1 to 48
# Data columns (total 52 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 1                    48 non-null     object
#  1   Notes of destination          0 non-null      float64
#  2   Location code of destination  48 non-null     int64
#  3   900                           48 non-null     object
#  4   947                           48 non-null     object
#  5   1833                          48 non-null     object
#  6   921                           48 non-null     object
#  7   1832                          48 non-null     object
#  8   1830                          48 non-null     object
#  9   1835                          48 non-null     object
#  10  927                           48 non-null     object
#  11  1829                          48 non-null     object
# ...

# %% [markdown]
# Resultados preliminares de la exploración:
# * El dataframe tabla1 es diferente al resto.
# * Los dataframe desde tabla2 hasta tabla8 tienen igual estructura: número de filas y número de columnas con sus nommbres. Cada uno de estos dataframe tienen datos del año en que se realizó el estudio. Los años van de cinco en cinco y empieza en 1990 hasta el 2020. Pero los dataframe no presentan una columna de año.

# %% [markdown]
# Tomando en cuenta lo anterior procedemos a realizar las siguientes transformaciones:

# %%
#Agregar una columna llamada "year" a cada dataframe cuyos valores serán el año que corresponda a cada uno.
tabla2['year'] = 2020
tabla3['year'] = 2015
tabla4['year'] = 2010
tabla5['year'] = 2005
tabla6['year'] = 2000
tabla7['year'] = 1995
tabla8['year'] = 1990

# %%
#Unimos los dataframes en uno solo
data_frames = [tabla2, tabla3, tabla4, tabla5, tabla6, tabla7, tabla8]
undesa = pd.concat(data_frames, ignore_index=True)

# %%
#Mostramos el nuevo dataset
undesa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 53 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 1                    336 non-null    object
#  1   Notes of destination          0 non-null      float64
#  2   Location code of destination  336 non-null    int64
#  3   900                           336 non-null    object
#  4   947                           336 non-null    object
#  5   1833                          336 non-null    object
#  6   921                           336 non-null    object
#  7   1832                          336 non-null    object
#  8   1830                          336 non-null    object
#  9   1835                          336 non-null    object
#  10  927                           336 non-null    object
#  11  1829                          336 non-null    object
# ...

# %%
#La columna "Notes of destination" tiene todos sus valores nulos por lo que procedemos a eliminarla
undesa["Notes of destination"].isnull().sum()
# Out:
# 336

# %%
undesa.drop(columns=['Notes of destination'], inplace=True)

# %%
#Renombramos columnas 
undesa.rename(columns={'Unnamed: 1': 'Region_group_of_destination'}, inplace=True)

# %%
nuevos_nombres = {
    '900': 'WORLD',
    '947': 'Sub-Saharan Africa',
    '1833': 'Northern Africa and Western Asia',
    '921': 'Central and Southern Asia',
    '1832': 'Eastern and South-Eastern Asia',
    '1830': 'Latin America and the Caribbean',
    '1835': 'Oceania (excluding Australia & New Zealand)',
    '927': 'Australia & New Zealand',
    '1829': 'Europe and Northern America',
    '901': 'Developed regions',
    '902': 'Less developed regions',
    '934': 'Less developed regions excluding least developed',
    '948': 'Less developed regions excluding China',
    '941': 'Least developed countries',
    '1636': 'Land-locked Developing Countries (LLDC)',
    '1637': 'Small island developing States (SIDS)',
    '1503': 'High-income countries',
    '1517': 'Middle-income countries',
    '1502': 'Upper-middle-income-countries',
    '1501': 'Lower-middle-income countries',
    '1500': 'Low-income countries',
    '903': 'AFRICA',
    '910': 'Eastern Africa',
    '911': 'Middle Africa',
    '912': 'Northern Africa',
    '913': 'Southern Africa',
    '914': 'Western Africa',
    '935': 'ASIA',
    '5500': 'Central Asia',
    '906': 'Eastern Asia',
    '920': 'South-Eastern Asia',
    '5501': 'Southern Asia',
    '922': 'Western Asia',
    '908': 'EUROPE',
    '923': 'Eastern Europe',
    '924': 'Northern Europe',
    '925': 'Southern Europe',
    '926': 'Western Europe',
    '904': 'LATIN AMERICA AND THE CARIBBEAN',
    '915': 'Caribbean',
    '916': 'Central America',
    '931': 'South America',
    '905': 'NORTHERN AMERICA',
    '909': 'OCEANIA',
    '927': 'Australia and New Zealand',
    '928': 'Melanesia',
    '954': 'Micronesia',
    '957': 'Polynesia',
    '2003': 'Other'
}

undesa.rename(columns=nuevos_nombres, inplace=True)

# %%
#Mostramos los cambios realizados
undesa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 52 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Region_group_of_destination                       336 non-null    object
#  1   Location code of destination                      336 non-null    int64
#  2   WORLD                                             336 non-null    object
#  3   Sub-Saharan Africa                                336 non-null    object
#  4   Northern Africa and Western Asia                  336 non-null    object
#  5   Central and Southern Asia                         336 non-null    object
#  6   Eastern and South-Eastern Asia                    336 non-null    object
#  7   Latin America and the Caribbean                   336 non-null    object
#  8   Oceania (excluding Australia & New Zealand)       336 non-null    object
# ...

# %%
undesa.head()
# Out:
#           Region_group_of_destination  Location code of destination  \
# 0                               WORLD                           900
# 1                  Sub-Saharan Africa                           947
# 2    Northern Africa and Western Asia                          1833
# 3           Central and Southern Asia                           921
# 4      Eastern and South-Eastern Asia                          1832
#
#          WORLD Sub-Saharan Africa Northern Africa and Western Asia  \
# 0  280 598 105         28 284 538                       37 563 820
# 1   22 221 538         17 808 594                        1 239 160
# 2   49 767 746          2 263 512                       19 145 437
# 3   19 427 576             56 069                          330 579
# 4   19 591 106             14 862                           29 006
#
#   Central and Southern Asia Eastern and South-Eastern Asia  \
# 0                51 229 549                     38 400 740
# ...

# %%
#Eliminación de columnas repetidas
undesa.drop(columns=['927.1'], inplace=True)

# %%
#Cambiamos los tipos de datos de las columnas
#Reemplazamos los valores no numéricos con cero
columns_a_convertir = undesa.columns[2:50]  # Índices de columna desde 2 hasta 49

for col in columns_a_convertir:
    undesa[col] = undesa[col].str.replace('[^\d]', '', regex=True)  # Eliminar caracteres no numéricos
    undesa[col] = undesa[col].replace('', np.nan)  # Reemplazar cadenas vacías por NaN
    undesa[col] = undesa[col].astype(float).fillna(0).astype(int)  # Convertir a float, rellenar NaN con 0, convertir a int

# %%
undesa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 51 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Region_group_of_destination                       336 non-null    object
#  1   Location code of destination                      336 non-null    int64
#  2   WORLD                                             336 non-null    int32
#  3   Sub-Saharan Africa                                336 non-null    int32
#  4   Northern Africa and Western Asia                  336 non-null    int32
#  5   Central and Southern Asia                         336 non-null    int32
#  6   Eastern and South-Eastern Asia                    336 non-null    int32
#  7   Latin America and the Caribbean                   336 non-null    int32
#  8   Oceania (excluding Australia & New Zealand)       336 non-null    int32
# ...

# %%
for idx, column_name in enumerate(undesa.columns):
    print(f"Número de columna: {idx}, Nombre de columna: {column_name}")
# Out:
# Número de columna: 0, Nombre de columna: Region_group_of_destination
# Número de columna: 1, Nombre de columna: Location code of destination
# Número de columna: 2, Nombre de columna: WORLD
# Número de columna: 3, Nombre de columna: Sub-Saharan Africa
# Número de columna: 4, Nombre de columna: Northern Africa and Western Asia
# Número de columna: 5, Nombre de columna: Central and Southern Asia
# Número de columna: 6, Nombre de columna: Eastern and South-Eastern Asia
# Número de columna: 7, Nombre de columna: Latin America and the Caribbean
# Número de columna: 8, Nombre de columna: Oceania (excluding Australia & New Zealand)
# Número de columna: 9, Nombre de columna: Australia and New Zealand
# Número de columna: 10, Nombre de columna: Europe and Northern America
# Número de columna: 11, Nombre de columna: Developed regions
# Número de columna: 12, Nombre de columna: Less developed regions
# Número de columna: 13, Nombre de columna: Less developed regions excluding least developed
# ...

# %%
# Eliminación de columnas no pertinentes
#El análisis estará concentrado en el continente americano
undesa.drop(undesa.columns[[3, 4, 5, 6, 8, 9, 14, 15, 16, 17, 18, 24, 25, 26, 27, 28, 30, 31, 32, 33, 34, 36, 37, 38, 39, 45, 46, 47, 48, 49]], axis=1, inplace=True)

# %%
undesa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 21 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Region_group_of_destination                       336 non-null    object
#  1   Location code of destination                      336 non-null    int64
#  2   WORLD                                             336 non-null    int32
#  3   Latin America and the Caribbean                   336 non-null    int32
#  4   Europe and Northern America                       336 non-null    int32
#  5   Developed regions                                 336 non-null    int32
#  6   Less developed regions                            336 non-null    int32
#  7   Less developed regions excluding least developed  336 non-null    int32
#  8   Middle-income countries                           336 non-null    int32
# ...

# %%
#Borramos columna duplicada
undesa.drop(undesa.columns[[15]], axis=1, inplace=True)

# %%
undesa.head()
# Out:
#           Region_group_of_destination  Location code of destination  \
# 0                               WORLD                           900
# 1                  Sub-Saharan Africa                           947
# 2    Northern Africa and Western Asia                          1833
# 3           Central and Southern Asia                           921
# 4      Eastern and South-Eastern Asia                          1832
#
#        WORLD  Latin America and the Caribbean  Europe and Northern America  \
# 0  280598105                         42890481                     67601621
# 1   22221538                            30679                       527437
# 2   49767746                            68381                      2772902
# 3   19427576                            14684                      4590984
# 4   19591106                           333438                       518524
#
#    Developed regions  Less developed regions  \
# 0           69815370               198125584
# ...

# %%
#Exportamos el archivo limpio para realizarle el EDA
ruta_archivo = "data/undesa.csv"  # Ruta completa al archivo CSV

undesa.to_csv(ruta_archivo, index=False)

# %%
undesa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 20 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Region_group_of_destination                       336 non-null    object
#  1   Location code of destination                      336 non-null    int64
#  2   WORLD                                             336 non-null    int32
#  3   Latin America and the Caribbean                   336 non-null    int32
#  4   Europe and Northern America                       336 non-null    int32
#  5   Developed regions                                 336 non-null    int32
#  6   Less developed regions                            336 non-null    int32
#  7   Less developed regions excluding least developed  336 non-null    int32
#  8   Middle-income countries                           336 non-null    int32
# ...
