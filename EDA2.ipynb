# %% [markdown]
# ## Transformaciones iniciales

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1) Lectura de archivos csv y carga en dataframes

# %%
consolidado_regiones = pd.read_csv("datasets\datasets_listos\consolidado.csv", sep=',', thousands=',')
america_latina = pd.read_csv("datasets\datasets_listos\latinoamerica.csv",sep=',', thousands=',')
consolidado_latino = pd.read_csv('datasets\datasets_listos\consolidado_america_latina.csv',sep=',', thousands=',')
canada = pd.read_csv('datasets\datasets_listos\canada.csv',sep=',', thousands=',')
eeuu = pd.read_csv('datasets\datasets_listos\eeuu.csv',sep=',', thousands=',')

# %% [markdown]
# #### 2) Transformación de tipos de datos adecuados y renombre de columnas

# %%
consolidado_regiones.head()
# Out:
#    Pais   Año  PIB per cápita (usd)  \
# 0  EEUU  1990                 23889
# 1  EEUU  1991                 24342
# 2  EEUU  1992                 25419
# 3  EEUU  1993                 26387
# 4  EEUU  1994                 27695
#
#    Población debajo del umbral de pobreza internacional  Tasa de empleo  \
# 0                                                0.5               62.8
# 1                                                0.5               61.7
# 2                                                0.5               61.5
# 3                                                0.5               61.7
# 4                                                0.5               62.5
#
#    Mortalidad infantil por cada 1000 nacimientos
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN

# %%
# Renombrar las columnas
nuevos_nombres = {'PIB per cápita (usd)': 'PIB', 'Población debajo del umbral de pobreza internacional': 'Pobreza',"Mortalidad infantil por cada 1000 nacimientos":"Mortalidad"}
consolidado_regiones = consolidado_regiones.rename(columns=nuevos_nombres)

# %%
consolidado_regiones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Pais            93 non-null     object
#  1   Año             93 non-null     int64
#  2   PIB             93 non-null     int64
#  3   Pobreza         89 non-null     float64
#  4   Tasa de empleo  69 non-null     float64
#  5   Mortalidad      73 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 4.5+ KB

# %%
consolidado_regiones["Pais"] = consolidado_regiones["Pais"].astype("category")

# %%
consolidado_latino.head()
# Out:
#                       Pais   Año  PIB per cápita (usd)  \
# 0  America latina y caribe  1990                5895.0
# 1  America latina y caribe  1991                5985.0
# 2  America latina y caribe  1992                6041.0
# 3  America latina y caribe  1993                6151.0
# 4  America latina y caribe  1994                6344.0
#
#    Población debajo del umbral de pobreza internacional  Tasa de empleo  \
# 0                                               16.8                NaN
# 1                                               16.1                NaN
# 2                                               15.9                NaN
# 3                                               15.7                NaN
# 4                                               14.4                NaN
#
#    Mortalidad infantil por cada 1000 nacimientos  \
# 0                                           43.7
# 1                                           41.9
# ...

# %%
# Renombrar las columnas
nuevos_nombres = {'PIB per cápita (usd)': 'PIB', 'Población debajo del umbral de pobreza internacional': 'Pobreza',"Mortalidad infantil por cada 1000 nacimientos":"Mortalidad","Tasa alfabetización mayores de 15":"Alfabetizacion","Promedio años de estudio personas economicamente activas mayores de 15":"Años de estudio"}
consolidado_latino = consolidado_latino.rename(columns=nuevos_nombres)

# %%
consolidado_latino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Pais             1085 non-null   object
#  1   Año              1085 non-null   int64
#  2   PIB              1083 non-null   float64
#  3   Pobreza          291 non-null    float64
#  4   Tasa de empleo   1075 non-null   float64
#  5   Mortalidad       1085 non-null   float64
#  6   Alfabetizacion   233 non-null    float64
#  7   Años de estudio  282 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 67.9+ KB

# %%
consolidado_latino["Pais"] = consolidado_latino["Pais"].astype("category")

# %%
america_latina.head()
# Out:
#                       Pais   Año  PIB per cápita (usd)  \
# 0  America latina y caribe  1990                  5895
# 1  America latina y caribe  1991                  5985
# 2  America latina y caribe  1992                  6041
# 3  America latina y caribe  1993                  6151
# 4  America latina y caribe  1994                  6344
#
#    Población debajo del umbral de pobreza internacional  Tasa de empleo  \
# 0                                               16.8                NaN
# 1                                               16.1                NaN
# 2                                               15.9                NaN
# 3                                               15.7                NaN
# 4                                               14.4                NaN
#
#    Mortalidad infantil por cada 1000 nacimientos  \
# 0                                           43.7
# 1                                           41.9
# ...

# %%
# Renombrar las columnas
nuevos_nombres = {'PIB per cápita (usd)': 'PIB', 'Población debajo del umbral de pobreza internacional': 'Pobreza',"Mortalidad infantil por cada 1000 nacimientos":"Mortalidad","Tasa alfabetización mayores de 15":"Alfabetizacion","Promedio años de estudio personas economicamente activas mayores de 15":"Años de estudio"}
america_latina = america_latina.rename(columns=nuevos_nombres)

# %%
america_latina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Pais             31 non-null     object
#  1   Año              31 non-null     int64
#  2   PIB              31 non-null     int64
#  3   Pobreza          31 non-null     float64
#  4   Tasa de empleo   21 non-null     float64
#  5   Mortalidad       31 non-null     float64
#  6   Alfabetizacion   31 non-null     float64
#  7   Años de estudio  21 non-null     float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 2.1+ KB

# %%
eeuu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Pais                                                  31 non-null     object
#  1   Año                                                   31 non-null     int64
#  2   PIB per cápita (usd)                                  31 non-null     int64
#  3   Población debajo del umbral de pobreza internacional  31 non-null     float64
#  4   Tasa de empleo                                        24 non-null     float64
#  5   Mortalidad infantil por cada 1000 nacimientos         21 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 1.6+ KB

# %%
# Renombrar las columnas
nuevos_nombres = {'PIB per cápita (usd)': 'PIB', 'Población debajo del umbral de pobreza internacional': 'Pobreza',"Mortalidad infantil por cada 1000 nacimientos":"Mortalidad"}
eeuu = eeuu.rename(columns=nuevos_nombres)

# %%
canada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Pais                                                    31 non-null     object
#  1   Año                                                     31 non-null     int64
#  2   PIB per cápita (usd)                                    31 non-null     int64
#  3   % población debajo del umbral de pobreza internacional  25 non-null     float64
#  4   Tasa de empleo                                          24 non-null     float64
#  5   Mortalidad infantil por cada 1000 nacimientos           21 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 1.6+ KB

# %%
# Renombrar las columnas
nuevos_nombres = {'PIB per cápita (usd)': 'PIB', '% población debajo del umbral de pobreza internacional': 'Pobreza',"Mortalidad infantil por cada 1000 nacimientos":"Mortalidad"}
canada = canada.rename(columns=nuevos_nombres)

# %%
america_latina["Pais"] = america_latina["Pais"].astype("category")
eeuu["Pais"] = eeuu["Pais"].astype("category")
canada["Pais"] = canada["Pais"].astype("category")

# %% [markdown]
# ## EDA

# %% [markdown]
# #### 3) Tratamiento de nulos
#
# Al tratarse de series de tiempo, vamos a interpolar los datos con interpolación lineal de manera que los valores faltantes se estimen utilizando una línea recta trazada entre los valores cercanos en el tiempo.

# %%
consolidado_regiones = consolidado_regiones.bfill(axis=0)
consolidado_latino = consolidado_latino.bfill(axis=0)
eeuu = eeuu.bfill(axis=0)
canada = canada.bfill(axis=0)
america_latina = america_latina.bfill(axis=0)

# %%
consolidado_regiones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Pais            93 non-null     category
#  1   Año             93 non-null     int64
#  2   PIB             93 non-null     int64
#  3   Pobreza         93 non-null     float64
#  4   Tasa de empleo  93 non-null     float64
#  5   Mortalidad      93 non-null     float64
# dtypes: category(1), float64(3), int64(2)
# memory usage: 4.0 KB

# %%
consolidado_latino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Pais             1085 non-null   category
#  1   Año              1085 non-null   int64
#  2   PIB              1083 non-null   float64
#  3   Pobreza          1079 non-null   float64
#  4   Tasa de empleo   1085 non-null   float64
#  5   Mortalidad       1085 non-null   float64
#  6   Alfabetizacion   1085 non-null   float64
#  7   Años de estudio  1079 non-null   float64
# dtypes: category(1), float64(6), int64(1)
# memory usage: 61.8 KB

# %%
eeuu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Pais            31 non-null     category
#  1   Año             31 non-null     int64
#  2   PIB             31 non-null     int64
#  3   Pobreza         31 non-null     float64
#  4   Tasa de empleo  24 non-null     float64
#  5   Mortalidad      31 non-null     float64
# dtypes: category(1), float64(3), int64(2)
# memory usage: 1.5 KB

# %%
canada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Pais            31 non-null     category
#  1   Año             31 non-null     int64
#  2   PIB             31 non-null     int64
#  3   Pobreza         29 non-null     float64
#  4   Tasa de empleo  24 non-null     float64
#  5   Mortalidad      31 non-null     float64
# dtypes: category(1), float64(3), int64(2)
# memory usage: 1.5 KB

# %%
america_latina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Pais             31 non-null     category
#  1   Año              31 non-null     int64
#  2   PIB              31 non-null     int64
#  3   Pobreza          31 non-null     float64
#  4   Tasa de empleo   31 non-null     float64
#  5   Mortalidad       31 non-null     float64
#  6   Alfabetizacion   31 non-null     float64
#  7   Años de estudio  31 non-null     float64
# dtypes: category(1), float64(5), int64(2)
# memory usage: 2.0 KB

# %%
consolidado_latino = consolidado_latino.ffill(axis=0)
eeuu = eeuu.ffill(axis=0)
canada = canada.ffill(axis=0)

# %%
canada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Pais            31 non-null     category
#  1   Año             31 non-null     int64
#  2   PIB             31 non-null     int64
#  3   Pobreza         31 non-null     float64
#  4   Tasa de empleo  31 non-null     float64
#  5   Mortalidad      31 non-null     float64
# dtypes: category(1), float64(3), int64(2)
# memory usage: 1.5 KB

# %% [markdown]
# #### 4) Verificación y tratamiento de duplicados

# %%
# Verificar duplicados en un DataFrame
duplicates_regiones = consolidado_regiones.duplicated()
duplicates_latino = consolidado_latino.duplicated()
duplicates_eeuu = eeuu.duplicated()
duplicates_canada = canada.duplicated()
duplicates_americalatina = america_latina.duplicated()

# Contar la cantidad de duplicados en cada DataFrame
print("Cantidad de duplicados en consolidado_regiones:", duplicates_regiones.sum())
print("Cantidad de duplicados en consolidado_latino:", duplicates_latino.sum())
print("Cantidad de duplicados en eeuu:", duplicates_eeuu.sum())
print("Cantidad de duplicados en canada:", duplicates_canada.sum())
print("Cantidad de duplicados en america_latina:", duplicates_americalatina.sum())
# Out:
# Cantidad de duplicados en consolidado_regiones: 0
# Cantidad de duplicados en consolidado_latino: 0
# Cantidad de duplicados en eeuu: 0
# Cantidad de duplicados en canada: 0
# Cantidad de duplicados en america_latina: 0

# %% [markdown]
# #### 5) Verificación y tratamiento de outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualizar box plots para identificar outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=consolidado_regiones["PIB"])
plt.title("Box Plot de PIB")
plt.xticks(rotation=45)
plt.show()

# %%
# Visualizar box plots para identificar outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=consolidado_regiones["Pobreza"])
plt.title("Box Plot de Tasa de Pobreza")
plt.xticks(rotation=45)
plt.show()

# %%
# Visualizar box plots para identificar outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=consolidado_regiones["Tasa de empleo"])
plt.title("Box Plot de Tasa de empleo")
plt.xticks(rotation=45)
plt.show()

# %%
# Visualizar box plots para identificar outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=consolidado_regiones["Mortalidad"])
plt.title("Box Plot de Mortalidad infantil")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### 6) Análisis y detección de patrones

# %% [markdown]
# a) Resúmen estadístico

# %%
# Por un lado haremos el resumen de america latina
summary = america_latina.describe()
print(summary)
# Out:
#                Año          PIB    Pobreza  Tasa de empleo  Mortalidad  \
# count    31.000000    31.000000  31.000000       31.000000   31.000000
# mean   2005.000000  7396.870968   9.983871       63.632258   24.538710
# std       9.092121  1007.957001   4.716361        1.341240    9.087892
# min    1990.000000  5895.000000   3.900000       60.700000   14.000000
# 25%    1997.500000  6623.000000   4.800000       62.400000   16.650000
# 50%    2005.000000  7209.000000  10.400000       63.800000   21.900000
# 75%    2012.500000  8519.000000  14.450000       64.800000   30.950000
# max    2020.000000  8811.000000  16.800000       65.600000   43.700000
#
#        Alfabetizacion  Años de estudio
# count       31.000000        31.000000
# mean        90.122581         8.538710
# std          2.799608         0.680528
# min         84.400000         7.900000
# 25%         88.250000         7.900000
# 50%         90.400000         8.300000
# 75%         92.400000         9.150000
# ...

# %%
# Canada
summary2 = canada.describe()
print(summary2)
# Out:
#                Año           PIB    Pobreza  Tasa de empleo  Mortalidad
# count    31.000000     31.000000  31.000000       31.000000   31.000000
# mean   2005.000000  34742.225806   0.229032       61.129032    5.061290
# std       9.092121  12268.556388   0.090161        1.553961    0.289456
# min    1990.000000  19998.000000   0.200000       57.900000    4.500000
# 25%    1997.500000  21874.000000   0.200000       60.150000    4.800000
# 50%    2005.000000  36383.000000   0.200000       61.800000    5.200000
# 75%    2012.500000  45751.500000   0.200000       61.800000    5.300000
# max    2020.000000  52669.000000   0.500000       63.500000    5.300000

# %%
# EEUUU
summary3 = eeuu.describe()
print(summary3)
# Out:
#                Año           PIB    Pobreza  Tasa de empleo  Mortalidad
# count    31.000000     31.000000  31.000000       31.000000   31.000000
# mean   2005.000000  43131.032258   0.829032       61.241935    6.532258
# std       9.092121  12689.815101   0.257156        2.215818    0.594075
# min    1990.000000  23889.000000   0.200000       58.400000    5.400000
# 25%    1997.500000  32156.500000   0.700000       58.600000    6.000000
# 50%    2005.000000  44123.000000   1.000000       62.200000    6.700000
# 75%    2012.500000  52537.500000   1.000000       62.950000    7.100000
# max    2020.000000  65120.000000   1.200000       64.400000    7.100000

# %% [markdown]
# d) Distribución de cada indicador en toda América

# %%
columns_to_plot = consolidado_regiones.columns[2:]
# Ploteo de histogramas para cada columna
for column in columns_to_plot:
    plt.figure(figsize=(8, 6))
    plt.hist(consolidado_regiones[column], bins=50, edgecolor='black')
    plt.title(f"Histograma de {column}")
    plt.xlabel(column)
    plt.ylabel("Frecuencia")
    plt.show()

# %% [markdown]
# e) Distribución de frecuencia de cada indicador por región específica: America latina, canada, eeuu

# %%
columns_to_plot = consolidado_regiones.columns[2:]
for column in columns_to_plot:
    plt.figure()
    
    if column in eeuu.columns:
        plt.hist(eeuu[column], bins=20, edgecolor='black')
        plt.title(f"Histograma de {column} - EEUU")
        plt.xlabel(column)
        plt.ylabel("Frecuencia")
        plt.show()
    
    if column in canada.columns:
        plt.hist(canada[column], bins=20, edgecolor='black')
        plt.title(f"Histograma de {column} - Canadá")
        plt.xlabel(column)
        plt.ylabel("Frecuencia")
        plt.show()
    
    if column in america_latina.columns:
        plt.hist(america_latina[column], bins=20, edgecolor='black')
        plt.title(f"Histograma de {column} - América Latina")
        plt.xlabel(column)
        plt.ylabel("Frecuencia")
        plt.show()

# %% [markdown]
# f) Vamos a analizar posibles relaciones entre pares de variables a través de un pairplot

# %%
# Ploteo de diagramas de dispersión con colores por categoría de región
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(consolidado_regiones, hue='Pais', diag_kind='kde')
plt.suptitle("Diagramas de Dispersión de Indicadores Socioeconómicos por Región", y=1.02)
plt.show()
# Out:
# c:\Users\nombre.apellido\Desktop\henry\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\nombre.apellido\Desktop\henry\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\nombre.apellido\Desktop\henry\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# g) Ahora veremos una comparativa de estos indicadores socioeconómicos por región para ver su comportamiento

# %%
# Años seleccionados
years_selected = [1990, 1995, 2000, 2005, 2010, 2015, 2020]

# Filtrar el DataFrame para incluir solo los años seleccionados
df_years = consolidado_regiones[consolidado_regiones['Año'].isin(years_selected)]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lista de nombres de indicadores en tu DataFrame consolidado_regiones
indicadores = ["PIB", "Pobreza", "Tasa de empleo", "Mortalidad"]

# Ciclo for para generar gráficos para cada indicador
for indicador in indicadores:
    # Agrupar por año y país y obtener la suma del indicador
    grouped_data = df_years.groupby(["Año", "Pais"])[indicador].sum().unstack()

    # Crear gráfico de barras apiladas
    ax = grouped_data.plot(kind="bar", stacked=True)

    # Agregar título y etiquetas
    plt.title(f"{indicador} por región a lo largo de los años")
    plt.xlabel("Año")
    plt.ylabel(indicador)

    plt.show()
# Out:
# C:\Users\nombre.apellido\AppData\Local\Temp\ipykernel_25908\1400991857.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = df_years.groupby(["Año", "Pais"])[indicador].sum().unstack()
# C:\Users\nombre.apellido\AppData\Local\Temp\ipykernel_25908\1400991857.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = df_years.groupby(["Año", "Pais"])[indicador].sum().unstack()
# ...

# %% [markdown]
# f) Y adentrandonos más en la región de américa latina, haremos una visualización similar pero para ver en detalle los indicadores en los paises dentro de la región

# %%
# Eliminar espacios en blanco de la columna 'Pais'
consolidado_latino['Pais'] = consolidado_latino['Pais'].str.strip()

# %%
# Años seleccionados
years_selected = [1990, 1995, 2000, 2005, 2010, 2015, 2020]

# Filtrar el DataFrame para incluir solo los años seleccionados
df_years2 = consolidado_latino[consolidado_latino['Año'].isin(years_selected)]

# %%
# Lista de países de América del Sur
paises_suramerica = ["Argentina", "Bolivia (Estado Plurinacional de)", "Brasil", "Chile", "Colombia", "Ecuador", "Guyana", "Paraguay", "Perú", "Suriname", "Uruguay", "Venezuela (República Bolivariana de)"]

# Crear un DataFrame filtrando los países de América del Sur
df_suramerica = df_years2[df_years2['Pais'].isin(paises_suramerica)]

# %%
# Lista de nombres de indicadores en tu DataFrame df_suramerica
indicadores = ["PIB", "Pobreza", "Tasa de empleo", "Mortalidad", "Alfabetizacion", "Años de estudio"]

# Ciclo for para generar gráficos para cada indicador solo para América del Sur
for indicador in indicadores:
    # Agrupar por año y país y obtener la suma del indicador
    grouped_data = df_suramerica.groupby(["Año", "Pais"])[indicador].sum().unstack()

    # Crear gráfico de barras apiladas
    ax = grouped_data.plot(kind="bar", stacked=True,legend = False)

    # Agregar título y etiquetas
    plt.title(f"{indicador} en América del Sur a lo largo de los años")
    plt.xlabel("Año")
    plt.ylabel(indicador)

    # Crear una leyenda desplegable
    ax.legend(labels=grouped_data.columns, title="Países", bbox_to_anchor=(1.05, 1), loc='upper left')
    

    plt.show()

# %%
# Ciclo for para generar gráficos de líneas para cada indicador solo para América del Sur
for indicador in indicadores:
    # Agrupar por año y país y obtener la suma del indicador
    grouped_data = df_suramerica.groupby(["Año", "Pais"])[indicador].sum().unstack()

    # Crear gráfico de líneas
    ax = grouped_data.plot(kind="line", legend= False)

    # Agregar título y etiquetas
    plt.title(f"{indicador} en América del Sur a lo largo de los años")
    plt.xlabel("Año")
    plt.ylabel(indicador)
    # Crear una leyenda desplegable
    ax.legend(labels=grouped_data.columns, title="Países", bbox_to_anchor=(1.05, 1), loc='upper left')
    
    plt.show()

# %%
# Años seleccionados
years_selected = [1990, 2000, 2010, 2020]

# Filtrar el DataFrame para incluir solo los años seleccionados
df_selected_years = df_suramerica[df_suramerica['Año'].isin(years_selected)]

# %%
# Lista de nombres de indicadores en tu DataFrame df_suramerica
indicadores = ["PIB", "Pobreza", "Tasa de empleo", "Mortalidad", "Alfabetizacion", "Años de estudio"]

# Ciclo for para generar gráficos para cada indicador solo para América del Sur
for indicador in indicadores:
    # Agrupar por año y país y obtener la suma del indicador
    grouped_data = df_selected_years.groupby(["Año", "Pais"])[indicador].sum().unstack()

    # Crear gráfico de barras apiladas
    ax = grouped_data.plot(kind="bar",width=0.8,legend=False)

    # Agregar título y etiquetas
    plt.title(f"{indicador} en América del Sur a lo largo de los años")
    plt.xlabel("Año")
    plt.ylabel(indicador)

    # Crear una leyenda desplegable
    ax.legend(labels=grouped_data.columns, title="Países", bbox_to_anchor=(1.05, 1), loc='upper left')
    
    plt.show()
